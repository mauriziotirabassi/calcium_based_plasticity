# %% [markdown]
# # Setup

# %%
# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['axes.formatter.useoffset'] = False
import matplotlib.pyplot as plt
import nest
import numpy as np
import os
import re

from pynestml.codegeneration.nest_code_generator_utils import NESTCodeGeneratorUtils

from matplotlib import rcParams

text_color = 'black' 
rcParams['text.color'] = text_color 
rcParams['axes.labelcolor'] = text_color 
rcParams['xtick.color'] = text_color 
rcParams['ytick.color'] = text_color 
plt.rc('font', size=12)          # controls default text sizes 
plt.rc('axes', titlesize=20)     # fontsize of the axes title 
plt.rc('axes', labelsize=20)    # fontsize of the x and y labels 
plt.rc('xtick', labelsize=20)    # fontsize of the tick labels 
plt.rc('ytick', labelsize=20)    # fontsize of the tick labels 
plt.rc('legend', fontsize=12)    # legend fontsize 
plt.rc('figure', titlesize=26)  # fontsize of the figure title
# Out:
#               -- N E S T --
#   Copyright (C) 2004 The NEST Initiative
#
#  Version: 3.7.0
#  Built: May 19 2024 15:53:53
#
#  This program is provided AS IS and comes with
#  NO WARRANTY. See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.

# %%
import warnings
warnings.filterwarnings("ignore", message="ANTLR runtime and generated code versions disagree:.*")

module_name, neuron_model_name, synapse_model_name = NESTCodeGeneratorUtils.generate_code_for(
    nestml_neuron_model= "iaf_cond_alpha.nestml",
    nestml_synapse_model= "stdp_synapse.nestml",
    module_name= "nestml_module",
    post_ports = ["post_spikes"],
    target_path = "target")
# Out:
# WARNING:root:PyGSL is not available. The stiffness test will be skipped.
# WARNING:root:Error when importing: No module named 'pygsl'
#               -- N E S T --
#   Copyright (C) 2004 The NEST Initiative
#
#  Version: 3.7.0
#  Built: May 19 2024 15:53:53
#
#  This program is provided AS IS and comes with
#  NO WARRANTY. See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.
#
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# [13,iaf_cond_alpha_nestml, WARNING, [21:25;21:25]]: Implicit casting from (compatible) type '1 / ms' to 'real'.
# [14,iaf_cond_alpha_nestml, WARNING, [24:25;24:25]]: Implicit casting from (compatible) type '1 / ms' to 'real'.
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# [54,iaf_cond_alpha_nestml, WARNING, [21:25;21:25]]: Implicit casting from (compatible) type '1 / ms' to 'real'.
# [55,iaf_cond_alpha_nestml, WARNING, [24:25;24:25]]: Implicit casting from (compatible) type '1 / ms' to 'real'.
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# WARNING:root:Under certain conditions, the propagator matrix is singular (contains infinities).
# WARNING:root:List of all conditions that result in a singular propagator:
# WARNING:root:	AMPA_Tau_1 = AMPA_Tau_2
# WARNING:root:	NMDA_Tau_1 = NMDA_Tau_2
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# line 1:24 extraneous input '*' expecting {'integer', 'real', 'string', 'boolean', 'void', '(', ',', NAME, UNSIGNED_INTEGER}
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ANTLR runtime and generated code versions disagree: 4.10!=4.13.0
# ...
# /opt/app-root/src/target/stdp_nestml__with_iaf_cond_alpha_nestml.h: In instantiation of 'nest::stdp_nestml__with_iaf_cond_alpha_nestml<targetidentifierT>::stdp_nestml__with_iaf_cond_alpha_nestml() [with targetidentifierT = nest::TargetIdentifierPtrRport]':
# /srv/main-spack-instance-2402/spack/opt/spack/linux-ubuntu20.04-x86_64/gcc-10.3.0/nest-3.7-awyiyw5eok4ymdw3gfwuaplgocwmrgjd/include/nest/connector_model.h:164:25:   required from 'nest::GenericConnectorModel<ConnectionT>::GenericConnectorModel(std::string) [with ConnectionT = nest::stdp_nestml__with_iaf_cond_alpha_nestml<nest::TargetIdentifierPtrRport>; std::string = std::__cxx11::basic_string<char>]'
# /srv/main-spack-instance-2402/spack/opt/spack/linux-ubuntu20.04-x86_64/gcc-10.3.0/nest-3.7-awyiyw5eok4ymdw3gfwuaplgocwmrgjd/include/nest/model_manager_impl.h:62:5:   required from 'void nest::ModelManager::register_connection_model(const string&) [with ConnectionT = nest::stdp_nestml__with_iaf_cond_alpha_nestml; std::string = std::__cxx11::basic_string<char>]'
# /srv/main-spack-instance-2402/spack/opt/spack/linux-ubuntu20.04-x86_64/gcc-10.3.0/nest-3.7-awyiyw5eok4ymdw3gfwuaplgocwmrgjd/include/nest/nest_impl.h:37:70:   required from 'void nest::register_connection_model(const string&) [with ConnectorModelT = nest::stdp_nestml__with_iaf_cond_alpha_nestml; std::string = std::__cxx11::basic_string<char>]'
# /opt/app-root/src/target/stdp_nestml__with_iaf_cond_alpha_nestml.h:604:84:   required from here
# /opt/app-root/src/target/stdp_nestml__with_iaf_cond_alpha_nestml.h:725:16: warning: unused variable '__resolution' [-Wunused-variable]
#   725 |   const double __resolution = nest::Time::get_resolution().get_ms();  // do not remove, this is necessary for the resolution() function
#       |                ^~~~~~~~~~~~
# /opt/app-root/src/target/stdp_nestml__with_iaf_cond_alpha_nestml.h: In instantiation of 'void nest::stdp_nestml__with_iaf_cond_alpha_nestml<targetidentifierT>::recompute_internal_variables() [with targetidentifierT = nest::TargetIdentifierPtrRport]':
# /opt/app-root/src/target/stdp_nestml__with_iaf_cond_alpha_nestml.h:755:3:   required from 'nest::stdp_nestml__with_iaf_cond_alpha_nestml<targetidentifierT>::stdp_nestml__with_iaf_cond_alpha_nestml() [with targetidentifierT = nest::TargetIdentifierPtrRport]'
# /srv/main-spack-instance-2402/spack/opt/spack/linux-ubuntu20.04-x86_64/gcc-10.3.0/nest-3.7-awyiyw5eok4ymdw3gfwuaplgocwmrgjd/include/nest/connector_model.h:164:25:   required from 'nest::GenericConnectorModel<ConnectionT>::GenericConnectorModel(std::string) [with ConnectionT = nest::stdp_nestml__with_iaf_cond_alpha_nestml<nest::TargetIdentifierPtrRport>; std::string = std::__cxx11::basic_string<char>]'
# /srv/main-spack-instance-2402/spack/opt/spack/linux-ubuntu20.04-x86_64/gcc-10.3.0/nest-3.7-awyiyw5eok4ymdw3gfwuaplgocwmrgjd/include/nest/model_manager_impl.h:62:5:   required from 'void nest::ModelManager::register_connection_model(const string&) [with ConnectionT = nest::stdp_nestml__with_iaf_cond_alpha_nestml; std::string = std::__cxx11::basic_string<char>]'
# /srv/main-spack-instance-2402/spack/opt/spack/linux-ubuntu20.04-x86_64/gcc-10.3.0/nest-3.7-awyiyw5eok4ymdw3gfwuaplgocwmrgjd/include/nest/nest_impl.h:37:70:   required from 'void nest::register_connection_model(const string&) [with ConnectorModelT = nest::stdp_nestml__with_iaf_cond_alpha_nestml; std::string = std::__cxx11::basic_string<char>]'
# /opt/app-root/src/target/stdp_nestml__with_iaf_cond_alpha_nestml.h:604:84:   required from here
# /opt/app-root/src/target/stdp_nestml__with_iaf_cond_alpha_nestml.h:711:16: warning: unused variable '__resolution' [-Wunused-variable]
#   711 |   const double __resolution = nest::Time::get_resolution().get_ms();  // do not remove, this is necessary for the resolution() function
#       |                ^~~~~~~~~~~~
# /opt/app-root/src/target/stdp_nestml__with_iaf_cond_alpha_nestml.h: In instantiation of 'nest::stdp_nestml__with_iaf_cond_alpha_nestml<targetidentifierT>::stdp_nestml__with_iaf_cond_alpha_nestml() [with targetidentifierT = nest::TargetIdentifierIndex]':
# /srv/main-spack-instance-2402/spack/opt/spack/linux-ubuntu20.04-x86_64/gcc-10.3.0/nest-3.7-awyiyw5eok4ymdw3gfwuaplgocwmrgjd/include/nest/connector_model.h:164:25:   required from 'nest::GenericConnectorModel<ConnectionT>::GenericConnectorModel(std::string) [with ConnectionT = nest::stdp_nestml__with_iaf_cond_alpha_nestml<nest::TargetIdentifierIndex>; std::string = std::__cxx11::basic_string<char>]'
# /srv/main-spack-instance-2402/spack/opt/spack/linux-ubuntu20.04-x86_64/gcc-10.3.0/nest-3.7-awyiyw5eok4ymdw3gfwuaplgocwmrgjd/include/nest/model_manager_impl.h:103:34:   required from 'void nest::ModelManager::register_specific_connection_model_(const string&) [with CompleteConnecionT = nest::stdp_nestml__with_iaf_cond_alpha_nestml<nest::TargetIdentifierIndex>; std::string = std::__cxx11::basic_string<char>]'
# /srv/main-spack-instance-2402/spack/opt/spack/linux-ubuntu20.04-x86_64/gcc-10.3.0/nest-3.7-awyiyw5eok4ymdw3gfwuaplgocwmrgjd/include/nest/model_manager_impl.h:67:80:   required from 'void nest::ModelManager::register_connection_model(const string&) [with ConnectionT = nest::stdp_nestml__with_iaf_cond_alpha_nestml; std::string = std::__cxx11::basic_string<char>]'
# /srv/main-spack-instance-2402/spack/opt/spack/linux-ubuntu20.04-x86_64/gcc-10.3.0/nest-3.7-awyiyw5eok4ymdw3gfwuaplgocwmrgjd/include/nest/nest_impl.h:37:70:   required from 'void nest::register_connection_model(const string&) [with ConnectorModelT = nest::stdp_nestml__with_iaf_cond_alpha_nestml; std::string = std::__cxx11::basic_string<char>]'
# /opt/app-root/src/target/stdp_nestml__with_iaf_cond_alpha_nestml.h:604:84:   required from here
# /opt/app-root/src/target/stdp_nestml__with_iaf_cond_alpha_nestml.h:725:16: warning: unused variable '__resolution' [-Wunused-variable]
#   725 |   const double __resolution = nest::Time::get_resolution().get_ms();  // do not remove, this is necessary for the resolution() function
#       |                ^~~~~~~~~~~~
# /opt/app-root/src/target/stdp_nestml__with_iaf_cond_alpha_nestml.h: In instantiation of 'void nest::stdp_nestml__with_iaf_cond_alpha_nestml<targetidentifierT>::recompute_internal_variables() [with targetidentifierT = nest::TargetIdentifierIndex]':
# /opt/app-root/src/target/stdp_nestml__with_iaf_cond_alpha_nestml.h:755:3:   required from 'nest::stdp_nestml__with_iaf_cond_alpha_nestml<targetidentifierT>::stdp_nestml__with_iaf_cond_alpha_nestml() [with targetidentifierT = nest::TargetIdentifierIndex]'
# /srv/main-spack-instance-2402/spack/opt/spack/linux-ubuntu20.04-x86_64/gcc-10.3.0/nest-3.7-awyiyw5eok4ymdw3gfwuaplgocwmrgjd/include/nest/connector_model.h:164:25:   required from 'nest::GenericConnectorModel<ConnectionT>::GenericConnectorModel(std::string) [with ConnectionT = nest::stdp_nestml__with_iaf_cond_alpha_nestml<nest::TargetIdentifierIndex>; std::string = std::__cxx11::basic_string<char>]'
# /srv/main-spack-instance-2402/spack/opt/spack/linux-ubuntu20.04-x86_64/gcc-10.3.0/nest-3.7-awyiyw5eok4ymdw3gfwuaplgocwmrgjd/include/nest/model_manager_impl.h:103:34:   required from 'void nest::ModelManager::register_specific_connection_model_(const string&) [with CompleteConnecionT = nest::stdp_nestml__with_iaf_cond_alpha_nestml<nest::TargetIdentifierIndex>; std::string = std::__cxx11::basic_string<char>]'
# /srv/main-spack-instance-2402/spack/opt/spack/linux-ubuntu20.04-x86_64/gcc-10.3.0/nest-3.7-awyiyw5eok4ymdw3gfwuaplgocwmrgjd/include/nest/model_manager_impl.h:67:80:   required from 'void nest::ModelManager::register_connection_model(const string&) [with ConnectionT = nest::stdp_nestml__with_iaf_cond_alpha_nestml; std::string = std::__cxx11::basic_string<char>]'
# /srv/main-spack-instance-2402/spack/opt/spack/linux-ubuntu20.04-x86_64/gcc-10.3.0/nest-3.7-awyiyw5eok4ymdw3gfwuaplgocwmrgjd/include/nest/nest_impl.h:37:70:   required from 'void nest::register_connection_model(const string&) [with ConnectorModelT = nest::stdp_nestml__with_iaf_cond_alpha_nestml; std::string = std::__cxx11::basic_string<char>]'
# /opt/app-root/src/target/stdp_nestml__with_iaf_cond_alpha_nestml.h:604:84:   required from here
# /opt/app-root/src/target/stdp_nestml__with_iaf_cond_alpha_nestml.h:711:16: warning: unused variable '__resolution' [-Wunused-variable]
#   711 |   const double __resolution = nest::Time::get_resolution().get_ms();  // do not remove, this is necessary for the resolution() function
#       |                ^~~~~~~~~~~~
# /opt/app-root/src/target/stdp_nestml__with_iaf_cond_alpha_nestml.h: In instantiation of 'bool nest::stdp_nestml__with_iaf_cond_alpha_nestml<targetidentifierT>::send(nest::Event&, size_t, const nest::stdp_nestml__with_iaf_cond_alpha_nestmlCommonSynapseProperties&) [with targetidentifierT = nest::TargetIdentifierPtrRport; size_t = long unsigned int]':
# /srv/main-spack-instance-2402/spack/opt/spack/linux-ubuntu20.04-x86_64/gcc-10.3.0/nest-3.7-awyiyw5eok4ymdw3gfwuaplgocwmrgjd/include/nest/connector_base.h:391:22:   required from 'void nest::Connector<ConnectionT>::send_to_all(size_t, const std::vector<nest::ConnectorModel*>&, nest::Event&) [with ConnectionT = nest::stdp_nestml__with_iaf_cond_alpha_nestml<nest::TargetIdentifierPtrRport>; size_t = long unsigned int]'
# /srv/main-spack-instance-2402/spack/opt/spack/linux-ubuntu20.04-x86_64/gcc-10.3.0/nest-3.7-awyiyw5eok4ymdw3gfwuaplgocwmrgjd/include/nest/connector_base.h:383:3:   required from here
# /opt/app-root/src/target/stdp_nestml__with_iaf_cond_alpha_nestml.h:497:22: warning: unused variable 'minus_dt' [-Wunused-variable]
#   497 |         const double minus_dt = t_lastspike_ - ( start->t_ + __dendritic_delay );
#       |                      ^~~~~~~~
# /opt/app-root/src/target/stdp_nestml__with_iaf_cond_alpha_nestml.h:453:18: warning: unused variable '__resolution' [-Wunused-variable]
#   453 |     const double __resolution = nest::Time::get_resolution().get_ms();  // do not remove, this is necessary for the resolution() function
#       |                  ^~~~~~~~~~~~
# /opt/app-root/src/target/stdp_nestml__with_iaf_cond_alpha_nestml.h:455:10: warning: variable 'get_thread' set but not used [-Wunused-but-set-variable]
#   455 |     auto get_thread = [tid]()
#       |          ^~~~~~~~~~
# /opt/app-root/src/target/stdp_nestml__with_iaf_cond_alpha_nestml.h: In instantiation of 'bool nest::stdp_nestml__with_iaf_cond_alpha_nestml<targetidentifierT>::send(nest::Event&, size_t, const nest::stdp_nestml__with_iaf_cond_alpha_nestmlCommonSynapseProperties&) [with targetidentifierT = nest::TargetIdentifierIndex; size_t = long unsigned int]':
# /srv/main-spack-instance-2402/spack/opt/spack/linux-ubuntu20.04-x86_64/gcc-10.3.0/nest-3.7-awyiyw5eok4ymdw3gfwuaplgocwmrgjd/include/nest/connector_base.h:391:22:   required from 'void nest::Connector<ConnectionT>::send_to_all(size_t, const std::vector<nest::ConnectorModel*>&, nest::Event&) [with ConnectionT = nest::stdp_nestml__with_iaf_cond_alpha_nestml<nest::TargetIdentifierIndex>; size_t = long unsigned int]'
# /srv/main-spack-instance-2402/spack/opt/spack/linux-ubuntu20.04-x86_64/gcc-10.3.0/nest-3.7-awyiyw5eok4ymdw3gfwuaplgocwmrgjd/include/nest/connector_base.h:383:3:   required from here
# /opt/app-root/src/target/stdp_nestml__with_iaf_cond_alpha_nestml.h:497:22: warning: unused variable 'minus_dt' [-Wunused-variable]
#   497 |         const double minus_dt = t_lastspike_ - ( start->t_ + __dendritic_delay );
#       |                      ^~~~~~~~
# /opt/app-root/src/target/stdp_nestml__with_iaf_cond_alpha_nestml.h:453:18: warning: unused variable '__resolution' [-Wunused-variable]
#   453 |     const double __resolution = nest::Time::get_resolution().get_ms();  // do not remove, this is necessary for the resolution() function
#       |                  ^~~~~~~~~~~~
# /opt/app-root/src/target/stdp_nestml__with_iaf_cond_alpha_nestml.h:455:10: warning: variable 'get_thread' set but not used [-Wunused-but-set-variable]
#   455 |     auto get_thread = [tid]()
#       |          ^~~~~~~~~~
# /opt/app-root/src/target/stdp_nestml__with_iaf_cond_alpha_nestml.h: In instantiation of 'void nest::stdp_nestml__with_iaf_cond_alpha_nestml<targetidentifierT>::update_internal_state_(double, double, const nest::stdp_nestml__with_iaf_cond_alpha_nestmlCommonSynapseProperties&) [with targetidentifierT = nest::TargetIdentifierPtrRport]':
# /opt/app-root/src/target/stdp_nestml__with_iaf_cond_alpha_nestml.h:516:9:   required from 'bool nest::stdp_nestml__with_iaf_cond_alpha_nestml<targetidentifierT>::send(nest::Event&, size_t, const nest::stdp_nestml__with_iaf_cond_alpha_nestmlCommonSynapseProperties&) [with targetidentifierT = nest::TargetIdentifierPtrRport; size_t = long unsigned int]'
# /srv/main-spack-instance-2402/spack/opt/spack/linux-ubuntu20.04-x86_64/gcc-10.3.0/nest-3.7-awyiyw5eok4ymdw3gfwuaplgocwmrgjd/include/nest/connector_base.h:391:22:   required from 'void nest::Connector<ConnectionT>::send_to_all(size_t, const std::vector<nest::ConnectorModel*>&, nest::Event&) [with ConnectionT = nest::stdp_nestml__with_iaf_cond_alpha_nestml<nest::TargetIdentifierPtrRport>; size_t = long unsigned int]'
# /srv/main-spack-instance-2402/spack/opt/spack/linux-ubuntu20.04-x86_64/gcc-10.3.0/nest-3.7-awyiyw5eok4ymdw3gfwuaplgocwmrgjd/include/nest/connector_base.h:383:3:   required from here
# /opt/app-root/src/target/stdp_nestml__with_iaf_cond_alpha_nestml.h:809:16: warning: unused variable '__resolution' [-Wunused-variable]
#   809 |   const double __resolution = timestep;  // do not remove, this is necessary for the resolution() function
#       |                ^~~~~~~~~~~~
# /opt/app-root/src/target/stdp_nestml__with_iaf_cond_alpha_nestml.h:810:8: warning: variable 'get_t' set but not used [-Wunused-but-set-variable]
#   810 |   auto get_t = [t_start](){ return t_start; };   // do not remove, this is in case the predefined time variable ``t`` is used in the NESTML model
#       |        ^~~~~
# /opt/app-root/src/target/stdp_nestml__with_iaf_cond_alpha_nestml.h: In instantiation of 'void nest::stdp_nestml__with_iaf_cond_alpha_nestml<targetidentifierT>::update_internal_state_(double, double, const nest::stdp_nestml__with_iaf_cond_alpha_nestmlCommonSynapseProperties&) [with targetidentifierT = nest::TargetIdentifierIndex]':
# /opt/app-root/src/target/stdp_nestml__with_iaf_cond_alpha_nestml.h:516:9:   required from 'bool nest::stdp_nestml__with_iaf_cond_alpha_nestml<targetidentifierT>::send(nest::Event&, size_t, const nest::stdp_nestml__with_iaf_cond_alpha_nestmlCommonSynapseProperties&) [with targetidentifierT = nest::TargetIdentifierIndex; size_t = long unsigned int]'
# /srv/main-spack-instance-2402/spack/opt/spack/linux-ubuntu20.04-x86_64/gcc-10.3.0/nest-3.7-awyiyw5eok4ymdw3gfwuaplgocwmrgjd/include/nest/connector_base.h:391:22:   required from 'void nest::Connector<ConnectionT>::send_to_all(size_t, const std::vector<nest::ConnectorModel*>&, nest::Event&) [with ConnectionT = nest::stdp_nestml__with_iaf_cond_alpha_nestml<nest::TargetIdentifierIndex>; size_t = long unsigned int]'
# /srv/main-spack-instance-2402/spack/opt/spack/linux-ubuntu20.04-x86_64/gcc-10.3.0/nest-3.7-awyiyw5eok4ymdw3gfwuaplgocwmrgjd/include/nest/connector_base.h:383:3:   required from here
# /opt/app-root/src/target/stdp_nestml__with_iaf_cond_alpha_nestml.h:809:16: warning: unused variable '__resolution' [-Wunused-variable]
#   809 |   const double __resolution = timestep;  // do not remove, this is necessary for the resolution() function
#       |                ^~~~~~~~~~~~
# /opt/app-root/src/target/stdp_nestml__with_iaf_cond_alpha_nestml.h:810:8: warning: variable 'get_t' set but not used [-Wunused-but-set-variable]
#   810 |   auto get_t = [t_start](){ return t_start; };   // do not remove, this is in case the predefined time variable ``t`` is used in the NESTML model
#       |        ^~~~~
# [100%] Linking CXX shared module nestml_module.so
# [100%] Built target nestml_module_module
# [100%] Built target nestml_module_module
# Install the project...
# -- Install configuration: ""
# -- Installing: /tmp/nestml_target_ac_oe3at/nestml_module.so

# %% [markdown]
# ## Useful Functions

# %%
# Runs the simulation
def simulate(spike_recorder, duration, vm_pre, vm_post, multimeter=None, zoom=False, interval=None):
    # Simulate
    nest.Simulate(duration)
    spikes = sd.get(['events'][0])

    #print(sd.events)
    fig, ax = plt.subplots(3, figsize = (18,10))

    ax[0].plot(vm_pre.events["times"], vm_pre.events["V_m"], color = "b", label = "Pre-synaptic potential")
    ax[0].plot(vm_post.events["times"], vm_post.events["V_m"], color = "orange",  label = "Post-synaptic potential")
    ax[0].set_title("Post-synptic neuron Potential")
    ax[0].set_ylabel("Vm [mV]")
    ax[0].legend()
    if zoom:
        ax[0].set_xlim(interval)

    ax[1].set_title("Rasterplot")
    ax[1].plot( spikes['times'][np.where(spikes['senders']==1)], spikes['senders'][np.where(spikes['senders']==1)], '.', markersize = 40, alpha = 0.5, color = "b", label = "Pre-synaptic spikes")
    ax[1].plot( spikes['times'][np.where(spikes['senders']==2)], spikes['senders'][np.where(spikes['senders']==2)]-1, '.', markersize = 40, alpha = 0.5,color = "orange", label = "Post-synaptic spikes")
    ax[1].legend()
    ax[1].set_ylabel("Neurons")
    ax[1].set_yticklabels("")
    if zoom:
        ax[1].set_xlim(interval)

    ax[2].plot(wr.events["times"], wr.events["weights"], color = 'r')
    ax[2].set_title("STDP")
    ax[2].set_ylabel("Weight [nS]")
    ax[2].set_xlabel("Time [ms]")
    if zoom:
        ax[2].set_xlim(interval)

    ax[3].plot(multimeter.events["times"], multimeter.events["g_AMPA"], color='blue', label="AMPA conductance")
    ax[3].plot(multimeter.events["times"], multimeter.events["g_NMDA"], color='green', label="NMDA conductance")
    ax[3].set_title("Synaptic Conductances")
    ax[3].set_ylabel("Conductance [nS]")
    ax[3].set_xlabel("Time [ms]")
    ax[3].legend()
    if zoom:
        ax[3].set_xlim(interval)

    fig.tight_layout()

# Compares the effects of the STDP assuming the simulation lasts 10s
def compare(vm_pre, vm_post):
    fig, ax = plt.subplots(1, 2, figsize = (18,7))

    ax[0].plot(vm_pre.events["times"], vm_pre.events["V_m"], color = "b", label = "Pre-synaptic potential")
    ax[0].plot(vm_post.events["times"], vm_post.events["V_m"], color = "orange",  label = "Post-synaptic potential")
    ax[0].set_title("First Spike")
    ax[0].set_ylabel("Vm [mV]")
    ax[0].set_xlim([1000,1100])
    ax[0].set_xlabel("Time [ms]")
    ax[0].legend()

    ax[1].plot(vm_pre.events["times"], vm_pre.events["V_m"], color = "b", label = "Pre-synaptic potential")
    ax[1].plot(vm_post.events["times"], vm_post.events["V_m"], color = "orange",  label = "Post-synaptic potential")
    ax[1].set_title("Last Spike")
    ax[1].set_ylabel("Vm [mV]")
    ax[1].set_xlim([9000, 9100])
    ax[1].set_xlabel("Time [ms]")
    ax[1].legend()

    fig.tight_layout()

# %% [markdown]
# # Simulation

# %%
#os.environ['LD_LIBRARY_PATH'] = '/tmp/nestml_target:' + os.environ.get('LD_LIBRARY_PATH', '')
nest.ResetKernel()
nest.Install("target/nestml_module")
nest.set_verbosity("M_ERROR")
# Out:
# Dec 04 17:16:16 Install [Info]:
#     loaded module target/nestml_module

# %%
print(nest.node_models)
print(nest.synapse_models)
# Out:
# ('volume_transmitter', 'weight_recorder', 'ac_generator', 'dc_generator', 'gamma_sup_generator', 'mip_generator', 'noise_generator', 'inhomogeneous_poisson_generator', 'poisson_generator', 'poisson_generator_ps', 'ppd_sup_generator', 'pulsepacket_generator', 'sinusoidal_poisson_generator', 'spike_generator', 'step_current_generator', 'step_rate_generator', 'sinusoidal_gamma_generator', 'aeif_cond_alpha', 'aeif_cond_alpha_astro', 'aeif_cond_alpha_multisynapse', 'aeif_cond_beta_multisynapse', 'aeif_cond_exp', 'aeif_psc_alpha', 'aeif_psc_exp', 'aeif_psc_delta', 'astrocyte_lr_1994', 'gif_cond_exp', 'gif_cond_exp_multisynapse', 'glif_cond', 'hh_cond_exp_traub', 'hh_cond_beta_gap_traub', 'hh_psc_alpha', 'hh_psc_alpha_gap', 'ht_neuron', 'iaf_chxk_2008', 'iaf_cond_alpha', 'iaf_cond_alpha_mc', 'iaf_cond_beta', 'iaf_cond_exp', 'iaf_cond_exp_sfa_rr', 'siegert_neuron', 'amat2_psc_exp', 'cm_default', 'eprop_iaf_bsshslm_2020', 'eprop_iaf_adapt_bsshslm_2020', 'eprop_readout_bsshslm_2020', 'gif_psc_exp', 'gif_psc_exp_multisynapse', 'glif_psc', 'glif_psc_double_alpha', 'iaf_chs_2007', 'iaf_psc_alpha', 'iaf_psc_alpha_multisynapse', 'iaf_psc_alpha_ps', 'iaf_psc_delta', 'iaf_psc_delta_ps', 'iaf_psc_exp', 'iaf_psc_exp_htum', 'iaf_psc_exp_multisynapse', 'iaf_psc_exp_ps', 'iaf_psc_exp_ps_lossless', 'iaf_tum_2000', 'ignore_and_fire', 'izhikevich', 'mat2_psc_exp', 'parrot_neuron', 'parrot_neuron_ps', 'pp_psc_delta', 'aeif_psc_delta_clopath', 'hh_psc_alpha_clopath', 'correlation_detector', 'correlomatrix_detector', 'correlospinmatrix_detector', 'spike_train_injector', 'gif_pop_psc_exp', 'erfc_neuron', 'ginzburg_neuron', 'mcculloch_pitts_neuron', 'gauss_rate_ipn', 'rate_transformer_gauss', 'lin_rate_ipn', 'lin_rate_opn', 'rate_transformer_lin', 'sigmoid_rate_ipn', 'rate_transformer_sigmoid', 'sigmoid_rate_gg_1998_ipn', 'rate_transformer_sigmoid_gg_1998', 'tanh_rate_ipn', 'tanh_rate_opn', 'rate_transformer_tanh', 'threshold_lin_rate_ipn', 'threshold_lin_rate_opn', 'rate_transformer_threshold_lin', 'multimeter', 'voltmeter', 'spike_recorder', 'spin_detector', 'spike_dilutor', 'pp_cond_exp_mc_urbanczik', 'iaf_cond_alpha_nestml', 'iaf_cond_alpha_nestml__with_stdp_nestml')
# ('bernoulli_synapse', 'bernoulli_synapse_hpc', 'bernoulli_synapse_lbl', 'clopath_synapse', 'clopath_synapse_hpc', 'clopath_synapse_lbl', 'cont_delay_synapse', 'cont_delay_synapse_hpc', 'cont_delay_synapse_lbl', 'diffusion_connection', 'eprop_synapse_bsshslm_2020', 'eprop_synapse_bsshslm_2020_hpc', 'eprop_learning_signal_connection_bsshslm_2020', 'gap_junction', 'ht_synapse', 'ht_synapse_hpc', 'ht_synapse_lbl', 'jonke_synapse', 'jonke_synapse_hpc', 'jonke_synapse_lbl', 'quantal_stp_synapse', 'quantal_stp_synapse_hpc', 'quantal_stp_synapse_lbl', 'rate_connection_delayed', 'rate_connection_instantaneous', 'sic_connection', 'static_synapse', 'static_synapse_hpc', 'static_synapse_lbl', 'static_synapse_hom_w', 'static_synapse_hom_w_hpc', 'static_synapse_hom_w_lbl', 'stdp_dopamine_synapse', 'stdp_dopamine_synapse_hpc', 'stdp_dopamine_synapse_lbl', 'stdp_nn_pre_centered_synapse', 'stdp_nn_pre_centered_synapse_hpc', 'stdp_nn_pre_centered_synapse_lbl', 'stdp_nn_restr_synapse', 'stdp_nn_restr_synapse_hpc', 'stdp_nn_restr_synapse_lbl', 'stdp_nn_symm_synapse', 'stdp_nn_symm_synapse_hpc', 'stdp_nn_symm_synapse_lbl', 'stdp_pl_synapse_hom', 'stdp_pl_synapse_hom_hpc', 'stdp_pl_synapse_hom_lbl', 'stdp_synapse', 'stdp_synapse_hpc', 'stdp_synapse_lbl', 'stdp_facetshw_synapse_hom', 'stdp_facetshw_synapse_hom_hpc', 'stdp_facetshw_synapse_hom_lbl', 'stdp_synapse_hom', 'stdp_synapse_hom_hpc', 'stdp_synapse_hom_lbl', 'stdp_triplet_synapse', 'stdp_triplet_synapse_hpc', 'stdp_triplet_synapse_lbl', 'tsodyks2_synapse', 'tsodyks2_synapse_hpc', 'tsodyks2_synapse_lbl', 'tsodyks_synapse', 'tsodyks_synapse_hpc', 'tsodyks_synapse_lbl', 'tsodyks_synapse_hom', 'tsodyks_synapse_hom_hpc', 'tsodyks_synapse_hom_lbl', 'urbanczik_synapse', 'urbanczik_synapse_hpc', 'urbanczik_synapse_lbl', 'vogels_sprekeler_synapse', 'vogels_sprekeler_synapse_hpc', 'vogels_sprekeler_synapse_lbl', 'stdp_nestml__with_iaf_cond_alpha_nestml', 'stdp_nestml__with_iaf_cond_alpha_nestml_hpc', 'stdp_nestml__with_iaf_cond_alpha_nestml_lbl')

# %%
# Define neuron and synapse models
neuron_model = "iaf_cond_alpha_nestml__with_stdp_nestml"
synapse_model = "stdp_nestml__with_iaf_cond_alpha_nestml"  # Spike-timing-dependent plasticity synapse

# Create two neurons: pre-synaptic and post-synaptic
pre_neuron = nest.Create(neuron_model, 1)
post_neuron = nest.Create(neuron_model, 1)

# Create a weight recorder to log changes in synaptic weights
wr = nest.Create("weight_recorder")
nest.SetDefaults(synapse_model, {"weight_recorder": wr[0]})  # Attach recorder to the STDP synapse

# Display default parameters for the neuron and synapse model and verify connections
print(nest.GetDefaults(neuron_model))
print(nest.GetDefaults(synapse_model))
# Out:
# {'available': (0,), 'beta_Ca': 0.001, 'C_m': 250.0, 'Ca': 0.0, 'capacity': (2,), 'E_L': -70.0, 'element_type': 'neuron', 'elementsize': 1056, 'frozen': False, 'g_L': 16.6667, 'global_id': 0, 'gsl_error_tol': 0.001, 'instantiations': (2,), 'local': True, 'model': 'iaf_cond_alpha_nestml__with_stdp_nestml', 'model_id': 100, 'node_uses_wfr': False, 'receptor_types': {'AMPA': 2, 'NMDA': 3, 'EXC_SPIKES': 1}, 'recordables': ('V_m', 'Ca_in', 'm_VDCC', 'h_VDCC', 'g_AMPA__X__AMPA', 'g_AMPA__DOLLAR__X__AMPA', 'g_NMDA__X__NMDA', 'g_NMDA__DOLLAR__X__NMDA', 'g_exc__X__exc_spikes', 'g_exc__X__exc_spikes__d', 'I_VDCC', 'I_AMPA', 'I_NMDA', 'I_NMDA_Ca', 'post_trace__for_stdp_nestml'), 'synaptic_elements': {}, 't_ref': 2.0, 'tau_Ca': 10000.0, 'thread': -1, 'thread_local_id': -1, 'type_id': 'iaf_cond_alpha_nestml__with_stdp_nestml', 'V_m': -70.0, 'V_reset': -60.0, 'V_th': -55.0, 'vp': -1, 'r': 0, 'Ca_in': 7e-05, 'm_VDCC': 0.0033523462002171146, 'h_VDCC': 0.9074264200384542, 'g_AMPA__X__AMPA': 0.0, 'g_AMPA__DOLLAR__X__AMPA': 0.0, 'g_NMDA__X__NMDA': 0.0, 'g_NMDA__DOLLAR__X__NMDA': 0.0, 'g_exc__X__exc_spikes': 0.0, 'g_exc__X__exc_spikes__d': 0.0, 'E_exc': 0.0, 'tau_syn_exc': 0.2, 'AMPA_Tau_1': 0.2, 'AMPA_Tau_2': 1.7, 'AMPA_g_peak': 0.1, 'AMPA_E_rev': 0.0, 'NMDA_Tau_1': 0.29, 'NMDA_Tau_2': 70.0, 'NMDA_g_peak': 0.55, 'NMDA_E_rev': -3.0, 'NMDA_Mg_scale': 2.552, 'NMDA_Mg_slope': 0.072, 'Mg_out': 1.0, 'VDCC_g_bar': 0.0744, 'VDCC_V_hm': -5.9, 'VDCC_k_m': 9.5, 'VDCC_tau_m': 1.0, 'VDCC_V_hh': -39.0, 'VDCC_k_h': -9.2, 'VDCC_tau_h': 27.0, 'Ca_rest': 7e-05, 'Ca_out': 0.002, 'Ca_tau': 12.0, 'Ca_X_volume': 0.0006585029999999998, 'Ca_eta': 0.04, 'Rgas': 8.314, 'Temp': 310.0, 'Farado': 9.6485e-11, 'post_trace__for_stdp_nestml': 0.0, 'tau_tr_post__for_stdp_nestml': 20.0}
# {'alpha': 1.0, 'delay': 1.0, 'element_type': 'synapse', 'has_delay': True, 'lambda': 0.01, 'mu_minus': 1.0, 'mu_plus': 1.0, 'num_connections': 0, 'receptor_type': 0, 'requires_symmetric': False, 'sizeof': 136, 'synapse_model': 'stdp_nestml__with_iaf_cond_alpha_nestml', 'synapse_modelid': 74, 'Wmax': 100.0, 'Wmin': 0.0, 'w': 1.0, 'weight': 1.0, 'weight_recorder': NodeCollection(metadata=None, model=weight_recorder, size=1, first=3), 'pre_trace': 0.0, 'tau_tr_pre': 20.0, 'tau_tr_post': 20.0}

# %%
# Create the synapse
syn_spec = nest.CollocatedSynapses(
    # {'synapse_model': synapse_model,
    #  'receptor_type': 1}, # General
    {'synapse_model': synapse_model,
     'receptor_type': 2}, # AMPA
    {'synapse_model': synapse_model,
     'receptor_type': 3} # NMDA
)

nest.Connect(pre_neuron, post_neuron, "one_to_one", syn_spec=syn_spec)

print(nest.GetConnections(pre_neuron, post_neuron))
# Out:
#  source   target               synapse model               weight   delay
# -------- -------- --------------------------------------- -------- -------
#       1        2 stdp_nestml__with_iaf_cond_alpha_nestml    1.000   1.000
#       1        2 stdp_nestml__with_iaf_cond_alpha_nestml    1.000   1.000

# %%
print(nest.GetDefaults(neuron_model)['recordables'])
# Out:
# ('V_m', 'Ca_in', 'm_VDCC', 'h_VDCC', 'g_AMPA__X__AMPA', 'g_AMPA__DOLLAR__X__AMPA', 'g_NMDA__X__NMDA', 'g_NMDA__DOLLAR__X__NMDA', 'g_exc__X__exc_spikes', 'g_exc__X__exc_spikes__d', 'I_VDCC', 'I_AMPA', 'I_NMDA', 'I_NMDA_Ca', 'post_trace__for_stdp_nestml')

# %%
# Define simulation parameters
duration = 10000  # Simulation time in milliseconds
frequency = 1  # Spike frequency in Hz
delta_t = -10  # Time shift in milliseconds (pre- vs. post-spike)
interval = 100.0 / frequency  # Interval between spikes

# Generate spike times for the spike generator
spike_times = np.arange(interval, duration, interval)
spike_generator = nest.Create("spike_generator", {"spike_times": spike_times})

# Adjust pre- and post-synaptic delays based on delta_t
if delta_t >= 0:
    delta_pre = 0.0
    delta_post = delta_t
else:
    delta_pre = -1 * delta_t
    delta_post = 0.0

# Connect the spike generator to the post-neuron via an NMDA synapse
nest.Connect(spike_generator, post_neuron, "one_to_one", {
    "synapse_model": "static_synapse",
    "weight": 500.0,  # Strong input weight
    "delay": 1.0 + delta_post,  # Adjusted delay
    "receptor_type" : 1 # Directly to V_m
})

# Connect the spike generator to the pre-neuron via an NMDA synapse
nest.Connect(spike_generator, pre_neuron, "one_to_one", {
    "synapse_model": "static_synapse",
    "weight": 500.0,  # Strong input weight
    "delay": 1.0 + delta_pre,  # Adjusted delay
    "receptor_type" : 1 # Directly to V_m
})

# Record spikes using a spike recorder
sd = nest.Create("spike_recorder")
nest.Connect(pre_neuron, sd)  # Connect pre-neuron to spike recorder
nest.Connect(post_neuron, sd)  # Connect post-neuron to spike recorder

# Record membrane potentials using voltmeters
vm_pre = nest.Create("voltmeter")
vm_post = nest.Create("voltmeter")
nest.Connect(vm_pre, pre_neuron)  # Connect voltmeter to pre-neuron
nest.Connect(vm_post, post_neuron)  # Connect voltmeter to post-neuron

# Record conductances in the postsynaptic neuron
multimeter = nest.Create('multimeter', 1, {'record_from': ['Ca_in', 'I_VDCC', 'm_VDCC', 'h_VDCC']})
nest.SetStatus(multimeter, {'interval': 0.1})
nest.Connect(multimeter, post_neuron)

# %%
# Simulate
nest.Simulate(duration)
# Out:
# Info: processing a postsynaptic spike at time t = 101.2 msInfo: processing a presynaptic spike at time t = 111.2 msInfo: processing a postsynaptic spike at time t = 101.2 msInfo: processing a presynaptic spike at time t = 111.2 msInfo: processing a postsynaptic spike at time t = 201.2 msInfo: processing a presynaptic spike at time t = 211.2 msInfo: processing a postsynaptic spike at time t = 201.2 msInfo: processing a presynaptic spike at time t = 211.2 msInfo: processing a postsynaptic spike at time t = 301.2 msInfo: processing a presynaptic spike at time t = 311.2 msInfo: processing a postsynaptic spike at time t = 301.2 msInfo: processing a presynaptic spike at time t = 311.2 msInfo: processing a postsynaptic spike at time t = 401.2 msInfo: processing a presynaptic spike at time t = 411.2 msInfo: processing a postsynaptic spike at time t = 401.2 msInfo: processing a presynaptic spike at time t = 411.2 msInfo: processing a postsynaptic spike at time t = 501.2 msInfo: processing a presynaptic spike at time t = 511.2 msInfo: processing a postsynaptic spike at time t = 501.2 msInfo: processing a presynaptic spike at time t = 511.2 msInfo: processing a postsynaptic spike at time t = 601.2 msInfo: processing a presynaptic spike at time t = 611.2 msInfo: processing a postsynaptic spike at time t = 601.2 msInfo: processing a presynaptic spike at time t = 611.2 msInfo: processing a postsynaptic spike at time t = 701.2 msInfo: processing a presynaptic spike at time t = 711.2 msInfo: processing a postsynaptic spike at time t = 701.2 msInfo: processing a presynaptic spike at time t = 711.2 msInfo: processing a postsynaptic spike at time t = 801.2 msInfo: processing a presynaptic spike at time t = 811.2 msInfo: processing a postsynaptic spike at time t = 801.2 msInfo: processing a presynaptic spike at time t = 811.2 msInfo: processing a postsynaptic spike at time t = 901.2 msInfo: processing a presynaptic spike at time t = 911.2 msInfo: processing a postsynaptic spike at time t = 901.2 msInfo: processing a presynaptic spike at time t = 911.2 msInfo: processing a postsynaptic spike at time t = 1001.2 msInfo: processing a presynaptic spike at time t = 1011.2 msInfo: processing a postsynaptic spike at time t = 1001.2 msInfo: processing a presynaptic spike at time t = 1011.2 msInfo: processing a postsynaptic spike at time t = 1101.2 msInfo: processing a presynaptic spike at time t = 1111.2 msInfo: processing a postsynaptic spike at time t = 1101.2 msInfo: processing a presynaptic spike at time t = 1111.2 msInfo: processing a postsynaptic spike at time t = 1201.2 msInfo: processing a presynaptic spike at time t = 1211.2 msInfo: processing a postsynaptic spike at time t = 1201.2 msInfo: processing a presynaptic spike at time t = 1211.2 msInfo: processing a postsynaptic spike at time t = 1301.2 msInfo: processing a presynaptic spike at time t = 1311.2 msInfo: processing a postsynaptic spike at time t = 1301.2 msInfo: processing a presynaptic spike at time t = 1311.2 msInfo: processing a postsynaptic spike at time t = 1401.2 msInfo: processing a presynaptic spike at time t = 1411.2 msInfo: processing a postsynaptic spike at time t = 1401.2 msInfo: processing a presynaptic spike at time t = 1411.2 msInfo: processing a postsynaptic spike at time t = 1501.2 msInfo: processing a presynaptic spike at time t = 1511.2 msInfo: processing a postsynaptic spike at time t = 1501.2 msInfo: processing a presynaptic spike at time t = 1511.2 msInfo: processing a postsynaptic spike at time t = 1601.2 msInfo: processing a presynaptic spike at time t = 1611.2 msInfo: processing a postsynaptic spike at time t = 1601.2 msInfo: processing a presynaptic spike at time t = 1611.2 msInfo: processing a postsynaptic spike at time t = 1701.2 msInfo: processing a presynaptic spike at time t = 1711.2 msInfo: processing a postsynaptic spike at time t = 1701.2 msInfo: processing a presynaptic spike at time t = 1711.2 msInfo: processing a postsynaptic spike at time t = 1801.2 m ...

# %%
multimeter.events
# Out:
# {'senders': array([2, 2, 2, ..., 2, 2, 2]),
#  'times': array([1.0000e-01, 2.0000e-01, 3.0000e-01, ..., 9.9988e+03, 9.9989e+03,
#         9.9990e+03]),
#  'Ca_in': array([1.35527862e+08, 1.92136129e+08, 2.33434325e+08, ...,
#         5.56957947e+08, 5.56938074e+08, 5.56918349e+08]),
#  'm_VDCC': array([0.00314491, 0.00295722, 0.00278739, ..., 0.00117481, 0.0011748 ,
#         0.00117478]),
#  'h_VDCC': array([0.90764569, 0.90786415, 0.90808181, ..., 0.9651233 , 0.96512905,
#         0.96513479]),
#  'I_VDCC': array([1.65399516, 1.03198435, 0.75491251, ..., 0.05978661, 0.05978759,
#         0.05978857])}

# %%
zoom = True
interval = [2000, 2800]

fig, ax = plt.subplots(5, figsize = (18, 28))

ax[0].plot(vm_pre.events["times"], vm_pre.events["V_m"], color = "b", label = "Pre-synaptic potential")
ax[0].plot(vm_post.events["times"], vm_post.events["V_m"], color = "orange",  label = "Post-synaptic potential")
ax[0].set_title("Post-synptic neuron Potential")
ax[0].set_ylabel("Vm [mV]")
ax[0].legend()
if zoom:
    ax[0].set_xlim(interval)

ax[1].set_title("Rasterplot")
ax[1].plot(sd.events['times'][np.where(sd.events['senders']==1)], sd.events['senders'][np.where(sd.events['senders']==1)], '.', markersize = 40, alpha = 0.5, color = "b", label = "Pre-synaptic spikes")
ax[1].plot(sd.events['times'][np.where(sd.events['senders']==2)], sd.events['senders'][np.where(sd.events['senders']==2)]-1, '.', markersize = 40, alpha = 0.5,color = "orange", label = "Post-synaptic spikes")
ax[1].legend()
ax[1].set_ylabel("Neurons")
ax[1].set_yticklabels("")
if zoom:
    ax[1].set_xlim(interval)

ax[2].plot(wr.events["times"], wr.events["weights"], color = 'r')
ax[2].set_title("STDP")
ax[2].set_ylabel("Weight [nS]")
ax[2].set_xlabel("Time [ms]")
if zoom:
    ax[2].set_xlim(interval)

events = nest.GetStatus(multimeter, "events")[0]
ax[3].plot(events["times"], events["I_VDCC"], color="g")
ax[3].set_title("Calcium Current (I_VDCC)")
ax[3].set_ylabel("I_VDCC [pA]")
ax[3].set_xlabel("Time [ms]")
if zoom:
    ax[3].set_xlim(interval)

# Calcium concentration
ax[4].plot(events["times"], events["Ca_in"], color="g")
ax[4].set_title("Calcium intracellular Concentration")
ax[4].set_ylabel("Ca_in [mol/um3]")
ax[4].set_xlabel("Time [ms]")
if zoom:
    ax[4].set_xlim(interval)
    
fig.tight_layout()

# %%
# # Simulate
# simulate(sd, duration, vm_pre, vm_post, zoom=True, interval=[2000, 2800])

# %%
# Check effects of LTP/LTD    
compare(vm_pre, vm_post)

# %% [markdown]
# # Streamline

# %%
def sim(
    duration,
    frequency,
    delta_t,
    interval,
    neuron_model="iaf_cond_alpha_nestml__with_stdp_nestml",
    synapse_model = "stdp_nestml__with_iaf_cond_alpha_nestml",
):
    nest.ResetKernel()
    nest.Install("target/nestml_module")
    nest.set_verbosity("M_ERROR")

    # Create two neurons: pre-synaptic and post-synaptic
    pre_neuron = nest.Create(neuron_model, 1)
    post_neuron = nest.Create(neuron_model, 1)

    # Create a weight recorder to log changes in synaptic weights
    wr = nest.Create("weight_recorder")
    nest.SetDefaults(synapse_model, {"weight_recorder": wr[0]})  # Attach recorder to the STDP synapse
    
    # Create the synapse
    syn_spec = nest.CollocatedSynapses(
        {'synapse_model': synapse_model,
         'receptor_type': 2}, # AMPA
        {'synapse_model': synapse_model,
         'receptor_type': 3} # NMDA
    )

    nest.Connect(pre_neuron, post_neuron, "one_to_one", syn_spec=syn_spec)

    # Generate spike times for the spike generator
    spike_times = np.arange(interval, duration, interval)
    spike_generator = nest.Create("spike_generator", {"spike_times": spike_times})

    # Adjust pre- and post-synaptic delays based on delta_t
    if delta_t >= 0:
        delta_pre = 0.0
        delta_post = delta_t
    else:
        delta_pre = -1 * delta_t
        delta_post = 0.0

#     # Connect the spike generator to the post-neuron via an NMDA synapse
#     nest.Connect(spike_generator, post_neuron, "one_to_one", {
#         "synapse_model": "static_synapse",
#         "weight": 500.0,  # Strong input weight
#         "delay": 1.0 + delta_post,  # Adjusted delay
#         "receptor_type" : 1 # Directly to V_m
#     })

#     # Connect the spike generator to the pre-neuron via an NMDA synapse
#     nest.Connect(spike_generator, pre_neuron, "one_to_one", {
#         "synapse_model": "static_synapse",
#         "weight": 500.0,  # Strong input weight
#         "delay": 1.0 + delta_pre,  # Adjusted delay
#         "receptor_type" : 1 # Directly to V_m
#     })

    syn_spec_spike_pre = nest.CollocatedSynapses(
        {'synapse_model':'static_synapse',
         'receptor_type': 1,
         'weight': 999.0,
         'delay': 1.0 + delta_pre},
        {'synapse_model':'static_synapse',
         'receptor_type': 2,
         'weight': 999.0,
         'delay': 1.0 + delta_pre}
    )
    nest.Connect(spike_generator, pre_neuron, "one_to_one", syn_spec=syn_spec_spike_pre)
    
    syn_spec_spike_post = nest.CollocatedSynapses(
        {'synapse_model':'static_synapse',
         'receptor_type': 1,
         'weight': 999.0,
         'delay': 1.0 + delta_post},
        {'synapse_model':'static_synapse',
         'receptor_type': 2,
         'weight': 999.0,
         'delay': 1.0 + delta_post}
    )
    nest.Connect(spike_generator, post_neuron, "one_to_one", syn_spec=syn_spec_spike_post)

    # Record spikes using a spike recorder
    sd = nest.Create("spike_recorder")
    nest.Connect(pre_neuron, sd)  # Connect pre-neuron to spike recorder
    nest.Connect(post_neuron, sd)  # Connect post-neuron to spike recorder

    # Record membrane potentials using voltmeters
    vm_pre = nest.Create("voltmeter")
    vm_post = nest.Create("voltmeter")
    nest.Connect(vm_pre, pre_neuron)  # Connect voltmeter to pre-neuron
    nest.Connect(vm_post, post_neuron)  # Connect voltmeter to post-neuron

    # Record conductances in the postsynaptic neuron
    mm = nest.Create('multimeter', 1, {'record_from': ['Ca_in', 'I_VDCC', 'm_VDCC', 'h_VDCC']})
    nest.SetStatus(mm, {'interval': 0.1})
    nest.Connect(mm, post_neuron)
    
    # Simulate
    nest.Simulate(duration)
    
    zoom = True
    interval = [2000, 2800]

    fig, ax = plt.subplots(5, figsize = (18, 26))

    # Plot pre-synaptic and post-synaptic potentials
    ax[0].plot(vm_pre.events["times"], vm_pre.events["V_m"], color = "b", label = "Pre-synaptic potential")
    ax[0].plot(vm_post.events["times"], vm_post.events["V_m"], color = "orange", label = "Post-synaptic potential")
    ax[0].set_title("Membrane Potential of Post-synaptic Neuron")
    ax[0].set_ylabel("Vm [mV]")
    ax[0].legend()
    if zoom:
        ax[0].set_xlim(interval)

    print(mm.events)
    # Plot Calcium Current through VDCC receptors (I_VDCC)
    events = nest.GetStatus(mm, "events")[0]
    ax[1].plot(events["times"], events["I_VDCC"], color="g")
    ax[1].set_title("Calcium Current through VDCC Receptors (I_VDCC)")
    ax[1].set_ylabel("I_VDCC [pA]")
    ax[1].set_xlabel("Time [ms]")
    if zoom:
        ax[1].set_xlim(interval)

    # Plot Calcium Current through AMPA receptors (I_AMPA)
    ax[2].plot(events["times"], events["m_VDCC"], color="g")
    ax[2].set_title("VDCC activation gating variable")
    ax[2].set_ylabel("I_AMPA [pA]")
    ax[2].set_xlabel("Time [ms]")
    if zoom:
        ax[2].set_xlim(interval)

    # Plot NMDA Current (I_NMDA)
    ax[3].plot(events["times"], events["h_VDCC"], color="g")
    ax[3].set_title("VDCC inactivation gating variable")
    ax[3].set_ylabel("I_NMDA [pA]")
    ax[3].set_xlabel("Time [ms]")
    if zoom:
        ax[3].set_xlim(interval)

    # Plot Intracellular Calcium Concentration (Ca_in)
    ax[4].plot(events["times"], events["Ca_in"], color="g")
    ax[4].set_title("Intracellular Calcium Concentration (Ca_in)")
    ax[4].set_ylabel("Ca_in [mol/μm³]")
    ax[4].set_xlabel("Time [ms]")
    if zoom:
        ax[4].set_xlim(interval)

    fig.tight_layout()

# %%
sim(duration = 10000, # Simulation time in milliseconds
    frequency = 1,  # Spike frequency in Hz
    delta_t = -10,  # Time shift in milliseconds (pre- vs. post-spike)
    interval = 100.0 / 1  # Interval between spikes
)
# Out:
# g a postsynaptic spike at time t = 8401.2 msInfo: processing a presynaptic spike at time t = 8411.2 msInfo: processing a postsynaptic spike at time t = 8501.2 msInfo: processing a presynaptic spike at time t = 8511.2 msInfo: processing a postsynaptic spike at time t = 8501.2 msInfo: processing a presynaptic spike at time t = 8511.2 msInfo: processing a postsynaptic spike at time t = 8601.2 msInfo: processing a presynaptic spike at time t = 8611.2 msInfo: processing a postsynaptic spike at time t = 8601.2 msInfo: processing a presynaptic spike at time t = 8611.2 msInfo: processing a postsynaptic spike at time t = 8701.2 msInfo: processing a presynaptic spike at time t = 8711.2 msInfo: processing a postsynaptic spike at time t = 8701.2 msInfo: processing a presynaptic spike at time t = 8711.2 msInfo: processing a postsynaptic spike at time t = 8801.2 msInfo: processing a presynaptic spike at time t = 8811.2 msInfo: processing a postsynaptic spike at time t = 8801.2 msInfo: processing a presynaptic spike at time t = 8811.2 msInfo: processing a postsynaptic spike at time t = 8901.2 msInfo: processing a presynaptic spike at time t = 8911.2 msInfo: processing a postsynaptic spike at time t = 8901.2 msInfo: processing a presynaptic spike at time t = 8911.2 msInfo: processing a postsynaptic spike at time t = 9001.2 msInfo: processing a presynaptic spike at time t = 9011.2 msInfo: processing a postsynaptic spike at time t = 9001.2 msInfo: processing a presynaptic spike at time t = 9011.2 msInfo: processing a postsynaptic spike at time t = 9101.2 msInfo: processing a presynaptic spike at time t = 9111.2 msInfo: processing a postsynaptic spike at time t = 9101.2 msInfo: processing a presynaptic spike at time t = 9111.2 msInfo: processing a postsynaptic spike at time t = 9201.2 msInfo: processing a presynaptic spike at time t = 9211.2 msInfo: processing a postsynaptic spike at time t = 9201.2 msInfo: processing a presynaptic spike at time t = 9211.2 msInfo: processing a postsynaptic spike at time t = 9301.2 msInfo: processing a presynaptic spike at time t = 9311.2 msInfo: processing a postsynaptic spike at time t = 9301.2 msInfo: processing a presynaptic spike at time t = 9311.2 msInfo: processing a postsynaptic spike at time t = 9401.2 msInfo: processing a presynaptic spike at time t = 9411.2 msInfo: processing a postsynaptic spike at time t = 9401.2 msInfo: processing a presynaptic spike at time t = 9411.2 msInfo: processing a postsynaptic spike at time t = 9501.2 msInfo: processing a presynaptic spike at time t = 9511.2 msInfo: processing a postsynaptic spike at time t = 9501.2 msInfo: processing a presynaptic spike at time t = 9511.2 msInfo: processing a postsynaptic spike at time t = 9601.2 msInfo: processing a presynaptic spike at time t = 9611.2 msInfo: processing a postsynaptic spike at time t = 9601.2 msInfo: processing a presynaptic spike at time t = 9611.2 msInfo: processing a postsynaptic spike at time t = 9701.2 msInfo: processing a presynaptic spike at time t = 9711.2 msInfo: processing a postsynaptic spike at time t = 9701.2 msInfo: processing a presynaptic spike at time t = 9711.2 msInfo: processing a postsynaptic spike at time t = 9801.2 msInfo: processing a presynaptic spike at time t = 9811.2 msInfo: processing a postsynaptic spike at time t = 9801.2 msInfo: processing a presynaptic spike at time t = 9811.2 msInfo: processing a postsynaptic spike at time t = 9901.2 msInfo: processing a presynaptic spike at time t = 9911.2 msInfo: processing a postsynaptic spike at time t = 9901.2 msInfo: processing a presynaptic spike at time t = 9911.2 msInfo: processing a postsynaptic spike at time t = 101.2 msInfo: processing a presynaptic spike at time t = 111.2 msInfo: processing a postsynaptic spike at time t = 101.2 msInfo: processing a presynaptic spike at time t = 111.2 msInfo: processing a postsynaptic spike at time t = 201.2 msInfo: processing a presynaptic spike at time t = 211.2 msInfo: processing a postsynaptic spike at ti ...
#        9.9990e+03]), 'Ca_in': array([1.35527862e+08, 1.92136129e+08, 2.33434325e+08, ...,
#        5.51014150e+08, 5.51038309e+08, 5.51062308e+08]), 'm_VDCC': array([0.00314491, 0.00295722, 0.00278739, ..., 0.00116982, 0.00116984,
#        0.00116986]), 'h_VDCC': array([0.90764569, 0.90786415, 0.90808181, ..., 0.96769273, 0.96768947,
#        0.96768623]), 'I_VDCC': array([1.65399516, 1.03198435, 0.75491251, ..., 0.06007796, 0.06007701,
#        0.06007607])}
